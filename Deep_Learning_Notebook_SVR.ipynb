# %%
import pandas as pd
import numpy as np
import sklearn
import joblib

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

# %%
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

# %%
print("pandas.__version__", pd.__version__, flush=True)
print("numpy.__version__", np.__version__, flush=True)
print("sklearn.__version__", sklearn.__version__, flush=True)
print("joblib.__version__", joblib.__version__, flush=True)
# Out:
# pandas.__version__ 1.0.3
# numpy.__version__ 1.19.2
# sklearn.__version__ 0.23.2
# joblib.__version__ 0.17.0

# %%
pipeline_file_name = "Used_Car_Price_Pipeline_SVR.pkl"

# %% [markdown]
# # Load Data and Select Features

# %%
# Read the raw data
raw_df = pd.read_csv("clean-testing-data.csv") 
raw_df
# Out:
#                id   region  price    year manufacturer  \
# 0      7316356412   auburn  15000  2013.0         ford
# 1      7314560853   auburn  19900  2004.0         ford
# 2      7313406529   auburn  14000  2012.0        honda
# 3      7312847466   auburn  22500  2001.0         ford
# 4      7312144944   auburn  15000  2017.0        dodge
# ...           ...      ...    ...     ...          ...
# 71901  7303112347  wyoming  15999  2018.0    chevrolet
# 71902  7302963673  wyoming  18000  2005.0    chevrolet
# 71903  7302963273  wyoming  18000  1990.0         jeep
# 71904  7302384818  wyoming   9800  1985.0       nissan
# 71905  7302338378  wyoming   6800  1997.0       jaguar
#
#                          model  condition  cylinders    fuel  odometer  \
# 0                    f-150 xlt  excellent        6.0     gas  128000.0
# 1              f250 super duty       good        8.0  diesel   88000.0
# 2                      odyssey  excellent        6.0     gas   95000.0
# 3                         f450       good        8.0  diesel  144700.0
# 4         charger rt 4dr sedan  excellent        8.0     gas   90000.0
# ...                        ...        ...        ...     ...       ...
# 71901                cruze, lt  excellent        4.0     gas   36465.0
# 71902    silverado 1500 lt 4x4  excellent        8.0     gas  130000.0
# 71903            gand wagoneer       good        8.0     gas  114400.0
# 71904  300zx coupe with t-tops   like new        6.0     gas  115000.0
# 71905          xk8 convertible       good        8.0     gas   69550.0
#
#       title_status transmission drive         size         type paint_color  \
# 0            clean    automatic   rwd    full-size        truck       black
# 1            clean    automatic   4wd    full-size       pickup        blue
# 2            clean    automatic   fwd    full-size     mini-van      silver
# 3            clean       manual   rwd    full-size        truck       white
# 4          rebuilt    automatic   rwd     mid-size        sedan        grey
# ...            ...          ...   ...          ...          ...         ...
# 71901        clean    automatic   fwd     mid-size        sedan       black
# 71902         lien    automatic   4wd    full-size        truck        blue
# 71903        clean    automatic   4wd    full-size          SUV       black
# 71904        clean    automatic   rwd  sub-compact    hatchback         red
# 71905        clean    automatic   rwd      compact  convertible       white
#
#       state        lat        long              posting_date
# 0        al  32.592000  -85.518900  2021-05-03T14:02:03-0500
# 1        al  32.547500  -85.468200  2021-04-29T17:19:18-0500
# 2        al  32.628739  -85.461820  2021-04-27T12:20:01-0500
# 3        al  32.630400  -85.401600  2021-04-26T11:15:36-0500
# 4        al  32.822400  -85.770400  2021-04-24T18:39:59-0500
# ...     ...        ...         ...                       ...
# 71901    wy  41.138284 -104.784799  2021-04-07T09:03:17-0600
# 71902    wy  43.452800 -110.739300  2021-04-06T21:04:03-0600
# 71903    wy  43.452800 -110.739300  2021-04-06T21:02:26-0600
# 71904    wy  41.143700 -104.796200  2021-04-05T18:10:52-0600
# 71905    wy  43.642930 -108.222976  2021-04-05T16:29:38-0600
#
# [71906 rows x 20 columns]

# %% [markdown]
# # Process Data for Machine Learning

# %%
training_df = raw_df.set_index("id")

# %%
def simple_category_map(df, column, category_map):
    if (not pd.api.types.is_numeric_dtype(df[column])):
        df[column] = df[column].map(category_map)
    print(f"Column {column}: {category_map}")
    print(df[column].describe())
    print("")
    return df

# %%
# convert condition into numbers
from mapping_values import vehicle_condition_map
training_df = simple_category_map(training_df, "condition", vehicle_condition_map)

# convert size into numbers
from mapping_values import vehicle_size_map
training_df = simple_category_map(training_df, "size", vehicle_size_map)
# Out:
# Column condition: {'new': 1, 'like new': 2, 'excellent': 3, 'good': 4, 'fair': 5, 'salvage': 6}
# count    71906.000000
# mean         3.260006
# std          0.752632
# min          1.000000
# 25%          3.000000
# 50%          3.000000
# 75%          4.000000
# max          5.000000
# Name: condition, dtype: float64
#
# Column size: {'compact': 1, 'sub-compact': 2, 'mid-size': 3, 'full-size': 4}
# count    71906.000000
# mean         3.296206
# std          0.990295
# min          1.000000
# 25%          3.000000
# 50%          4.000000
# 75%          4.000000
# max          4.000000
# Name: size, dtype: float64

# %%
# convert drive into category
if ("fwd" not in training_df.columns or "rwd" not in training_df.columns):      
    fwd = (training_df["drive"] == "fwd") | (training_df["drive"] == "4wd")
    rwd = (training_df["drive"] == "rwd") | (training_df["drive"] == "4wd")
    training_df["fwd"] = (fwd * 1)
    training_df["rwd"] = (rwd * 1)
    
if ("drive" in training_df.columns):    
    training_df = training_df.drop(["drive"], axis=1)

print(f"Column fwd")
print(training_df["fwd"].describe())
print("")
print(f"Column rwd")
print(training_df["rwd"].describe())
# Out:
# Column fwd
# count    71906.000000
# mean         0.779671
# std          0.414472
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Name: fwd, dtype: float64
#
# Column rwd
# count    71906.000000
# mean         0.633911
# std          0.481738
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Name: rwd, dtype: float64

# %%
print(list(training_df.columns))
training_df
# Out:
# ['region', 'price', 'year', 'manufacturer', 'model', 'condition', 'cylinders', 'fuel', 'odometer', 'title_status', 'transmission', 'size', 'type', 'paint_color', 'state', 'lat', 'long', 'posting_date', 'fwd', 'rwd']
#              region  price    year manufacturer                    model  \
# id
# 7316356412   auburn  15000  2013.0         ford                f-150 xlt
# 7314560853   auburn  19900  2004.0         ford          f250 super duty
# 7313406529   auburn  14000  2012.0        honda                  odyssey
# 7312847466   auburn  22500  2001.0         ford                     f450
# 7312144944   auburn  15000  2017.0        dodge     charger rt 4dr sedan
# ...             ...    ...     ...          ...                      ...
# 7303112347  wyoming  15999  2018.0    chevrolet                cruze, lt
# 7302963673  wyoming  18000  2005.0    chevrolet    silverado 1500 lt 4x4
# 7302963273  wyoming  18000  1990.0         jeep            gand wagoneer
# 7302384818  wyoming   9800  1985.0       nissan  300zx coupe with t-tops
# 7302338378  wyoming   6800  1997.0       jaguar          xk8 convertible
#
#             condition  cylinders    fuel  odometer title_status transmission  \
# id
# 7316356412          3        6.0     gas  128000.0        clean    automatic
# 7314560853          4        8.0  diesel   88000.0        clean    automatic
# 7313406529          3        6.0     gas   95000.0        clean    automatic
# 7312847466          4        8.0  diesel  144700.0        clean       manual
# 7312144944          3        8.0     gas   90000.0      rebuilt    automatic
# ...               ...        ...     ...       ...          ...          ...
# 7303112347          3        4.0     gas   36465.0        clean    automatic
# 7302963673          3        8.0     gas  130000.0         lien    automatic
# 7302963273          4        8.0     gas  114400.0        clean    automatic
# 7302384818          2        6.0     gas  115000.0        clean    automatic
# 7302338378          4        8.0     gas   69550.0        clean    automatic
#
#             size         type paint_color state        lat        long  \
# id
# 7316356412     4        truck       black    al  32.592000  -85.518900
# 7314560853     4       pickup        blue    al  32.547500  -85.468200
# 7313406529     4     mini-van      silver    al  32.628739  -85.461820
# 7312847466     4        truck       white    al  32.630400  -85.401600
# 7312144944     3        sedan        grey    al  32.822400  -85.770400
# ...          ...          ...         ...   ...        ...         ...
# 7303112347     3        sedan       black    wy  41.138284 -104.784799
# 7302963673     4        truck        blue    wy  43.452800 -110.739300
# 7302963273     4          SUV       black    wy  43.452800 -110.739300
# 7302384818     2    hatchback         red    wy  41.143700 -104.796200
# 7302338378     1  convertible       white    wy  43.642930 -108.222976
#
#                         posting_date  fwd  rwd
# id
# 7316356412  2021-05-03T14:02:03-0500    0    1
# 7314560853  2021-04-29T17:19:18-0500    1    1
# 7313406529  2021-04-27T12:20:01-0500    1    0
# 7312847466  2021-04-26T11:15:36-0500    0    1
# 7312144944  2021-04-24T18:39:59-0500    0    1
# ...                              ...  ...  ...
# 7303112347  2021-04-07T09:03:17-0600    1    0
# 7302963673  2021-04-06T21:04:03-0600    1    1
# 7302963273  2021-04-06T21:02:26-0600    1    1
# 7302384818  2021-04-05T18:10:52-0600    0    1
# 7302338378  2021-04-05T16:29:38-0600    0    1
#
# [71906 rows x 20 columns]

# %% [markdown]
# # Select Training Features

# %%
# Scale the training data to better train
def scale_data(y, y_train, y_test):
    '''
        return the scaled training and testing data with the scaler
    '''
    y_scaler = MinMaxScaler().fit(y)
    # apply the scale to training and testing data sets
    y_train_scaled = y_scaler.transform(y_train)
    y_test_scaled = y_scaler.transform(y_test)
    #
    return y_train_scaled, y_test_scaled, y_scaler

# %%
# shuffle our data to remove any potential bias
training_df = sklearn.utils.shuffle(training_df)

# %%
# Select the features to train the data
target_feature = "price"

# no nulls for the selected features
selected_features = [
#     "id",
#     "region",
#     "price",
    "year",
#     "manufacturer",
#     "model",
    "condition",
#     "cylinders",
#     "fuel",
    "odometer",
#     "title_status",
    "transmission",
    "size",
    "type",
#     "paint_color",
    "state",
#     "lat",
#     "long",
#     "posting_date",
    "fwd",
    "rwd",
]

# just in case we left in the selected feature
if target_feature in selected_features:
    selected_features.remove(target_feature)
    
# just in case we loose a feature
for feature in selected_features:
    if (feature not in training_df.columns):
        selected_features.remove(feature)
        print(f"Feature '{feature}' was dropped because it was missing from training dataframe!")

X = training_df[selected_features]
y = training_df[target_feature].values.ravel()
print(X.shape, y.shape)
# Out:
# (71906, 9) (71906,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
print("train\t", X_train.shape, y_train.shape)
print("test\t", X_test.shape, y_test.shape)
# Out:
# train	 (53929, 9) (53929,)
# test	 (17977, 9) (17977,)

# %% [markdown]
# # Select Column Transformer

# %%
one_hot_encoding_columns = [
#     "id",
#     "region",
#     "price",
#     "year",
#     "manufacturer",
#     "model",
#     "condition",
#     "cylinders",
#     "fuel",
#     "odometer",
#     "title_status",
    "transmission",
#     "size",
    "type",
#     "paint_color",
    "state",
#     "lat",
#     "long",
#     "posting_date",
#     "fwd",
#     "rwd",
]

min_max_columns = [
#     "id",
#     "region",
#     "price",
    "year",
#     "manufacturer",
#     "model",
    "condition",
#     "cylinders",
#     "fuel",
    "odometer",
#     "title_status",
#     "transmission",
    "size",
#     "type",
#     "paint_color",
#     "state",
#     "lat",
#     "long",
#     "posting_date",
#     "fwd",
#     "rwd",
]

column_transformer = make_column_transformer(
    (
        OneHotEncoder(
            categories="auto",
            handle_unknown="ignore"
        ), 
        one_hot_encoding_columns
    ),
    (MinMaxScaler(), min_max_columns),
    remainder="passthrough",
    n_jobs=-1,
    verbose=True,
)
column_transformer
# Out:
# ColumnTransformer(n_jobs=-1, remainder='passthrough',
#                   transformers=[('onehotencoder',
#                                  OneHotEncoder(handle_unknown='ignore'),
#                                  ['transmission', 'type', 'state']),
#                                 ('minmaxscaler', MinMaxScaler(),
#                                  ['year', 'condition', 'odometer', 'size'])],
#                   verbose=True)

# %% [markdown]
# # Select Model

# %%
clf = SVR(
    kernel="linear", 
#     degree=3,
    gamma='scale',
#     coef0=0.0,
    tol=0.001,
    C=1.0,
#     epsilon=0.1,
#     shrinking=True,
    cache_size=200,
    verbose=True,
#     max_iter=-1,
)
clf
# Out:
# SVR(kernel='linear', verbose=True)

# %% [markdown]
# # Create Deep Learning Pipeline

# %%
pipeline = make_pipeline(column_transformer, clf, verbose=True)
pipeline
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(n_jobs=-1, remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['transmission', 'type',
#                                                    'state']),
#                                                  ('minmaxscaler',
#                                                   MinMaxScaler(),
#                                                   ['year', 'condition',
#                                                    'odometer', 'size'])],
#                                    verbose=True)),
#                 ('svr', SVR(kernel='linear', verbose=True))],
#          verbose=True)

# %%
pipeline.fit(X_train, y_train)
# Out:
# [Pipeline] . (step 1 of 2) Processing columntransformer, total=   3.4s
# [LibSVM][Pipeline] ............... (step 2 of 2) Processing svr, total= 2.9min
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(n_jobs=-1, remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['transmission', 'type',
#                                                    'state']),
#                                                  ('minmaxscaler',
#                                                   MinMaxScaler(),
#                                                   ['year', 'condition',
#                                                    'odometer', 'size'])],
#                                    verbose=True)),
#                 ('svr', SVR(kernel='linear', verbose=True))],
#          verbose=True)

# %% [markdown]
# # Score Deep Learning Pipeline

# %%
pipeline.score(X_test, y_test)
# Out:
# 0.22195677477270048

# %% [markdown]
# # Save Deep Learning Pipeline

# %%
joblib.dump(pipeline, pipeline_file_name)
# Out:
# ['Used_Car_Price_Pipeline_SVR.pkl']

# %%
print("When you send in the data to predict the value, use these columns in this order!")
print(list(X.columns.values))
# Out:
# When you send in the data to predict the value, use these columns in this order!
# ['year', 'condition', 'odometer', 'transmission', 'size', 'type', 'state', 'fwd', 'rwd']

# %% [markdown]
# # Testing Loading the Model

# %%
def submit_model(vehicle_as_dict, sorted_columns, pipeline_file):
    # set the first value as a list
    for key in vehicle_as_dict:
        vehicle_as_dict[key] = [vehicle_as_dict[key]]
        break
    # create the the dataframe
    testing_vehicle = pd.DataFrame.from_dict(vehicle_as_dict, orient='columns')
    # sorting columns into order
    testing_vehicle = testing_vehicle[sorted_columns]
    # load the model from disk
    testing_pipeline = joblib.load(pipeline_file)
    vehicle_testing_results = testing_pipeline.predict(testing_vehicle)
    testing_result = round(vehicle_testing_results[0], 2)
    print("testing_result: ", testing_result, flush=True)
    return testing_result

# %%
print(submit_model(X.iloc[-1].to_dict(), X.columns.values, pipeline_file_name))
# Out:
# testing_result:  12171.66
# 12171.66

# %%
print(submit_model(X.iloc[-2].to_dict(), X.columns.values, pipeline_file_name))
# Out:
# testing_result:  11600.99
# 11600.99

# %%
print(submit_model(X.iloc[-3].to_dict(), X.columns.values, pipeline_file_name))
# Out:
# testing_result:  6778.8
# 6778.8
